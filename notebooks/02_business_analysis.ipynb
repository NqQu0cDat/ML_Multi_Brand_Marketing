# %% [markdown]
# # Multi-Brand Marketing Campaign Performance Analysis

# %% [markdown]
# ## 1. Import libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 2. Load dataset

# %%
du_lieu = pd.read_csv('../data/processed/marketing_campaigns_features.csv')
du_lieu['Date'] = pd.to_datetime(du_lieu['Date'])
du_lieu.head()

# %% [markdown]
# ## 3. Dataset overview

# %%
du_lieu.shape

# %% [markdown]
# ## 4. Check missing values

# %%
du_lieu.isna().sum()

# %% [markdown]
# ## 5. Check duplicated rows

# %%
du_lieu.duplicated().sum()

# %% [markdown]
# ## 6. Check data types

# %%
du_lieu.dtypes

# %% [markdown]
# ## 7. Summary statistics

# %%
du_lieu.describe().T

# %% [markdown]
# ## 8. KPI overview
# - Total Revenue: **85,650,246,071**
# - Average ROI: **2.691**
# - Average CTR: **8.50%**
# - Average CVR: **54.96%**
# - Average CPA: **2.076**

# %% [markdown]
# ## 9. Brand Analysis

# %% [markdown]
# ![03_revenue_by_brand.png](../results/plots/eda/03_revenue_by_brand.png)

# %% [markdown]
# ![04_average_roi_by_brand.png](../results/plots/eda/04_average_roi_by_brand.png)

# %% [markdown]
# ![19_acquisition_cost_by_brand.png](../results/plots/business/19_acquisition_cost_by_brand.png)

# %% [markdown]
# ![20_average_cpa_by_brand.png](../results/plots/business/20_average_cpa_by_brand.png)

# %% [markdown]
# ![21_ctr_cvr_by_brand.png](../results/plots/business/21_ctr_cvr_by_brand.png)

# %% [markdown]
# ## 10. Channel Analysis

# %% [markdown]
# ![05_revenue_by_channel_used.png](../results/plots/eda/05_revenue_by_channel_used.png)

# %% [markdown]
# ![06_average_roi_by_channel_used.png](../results/plots/eda/06_average_roi_by_channel_used.png)

# %% [markdown]
# ![13_ctr_by_channel_used.png](../results/plots/eda/13_ctr_by_channel_used.png)

# %% [markdown]
# ![14_cvr_by_channel_used.png](../results/plots/eda/14_cvr_by_channel_used.png)

# %% [markdown]
# ![30_cpa_by_channel_used.png](../results/plots/business/30_cpa_by_channel_used.png)

# %% [markdown]
# ## 11. Campaign Type Analysis

# %% [markdown]
# ![07_revenue_by_campaign_type.png](../results/plots/eda/07_revenue_by_campaign_type.png)

# %% [markdown]
# ![15_cpa_by_campaign_type.png](../results/plots/eda/15_cpa_by_campaign_type.png)

# %% [markdown]
# ![22_average_roi_by_campaign_type.png](../results/plots/business/22_average_roi_by_campaign_type.png)

# %% [markdown]
# ![23_campaign_count_by_campaign_type.png](../results/plots/business/23_campaign_count_by_campaign_type.png)

# %% [markdown]
# ## 12. Customer Segment Analysis

# %% [markdown]
# ![08_revenue_by_customer_segment.png](../results/plots/eda/08_revenue_by_customer_segment.png)

# %% [markdown]
# ![24_roi_by_customer_segment.png](../results/plots/business/24_roi_by_customer_segment.png)

# %% [markdown]
# ![25_cvr_by_customer_segment.png](../results/plots/business/25_cvr_by_customer_segment.png)

# %% [markdown]
# ![26_heatmap_brand_customer_segment_revenue.png](../results/plots/business/26_heatmap_brand_customer_segment_revenue.png)

# %% [markdown]
# ## 13. Time Trend Analysis

# %% [markdown]
# ![09_revenue_trend_by_month.png](../results/plots/eda/09_revenue_trend_by_month.png)

# %% [markdown]
# ![10_campaign_count_by_month.png](../results/plots/eda/10_campaign_count_by_month.png)

# %% [markdown]
# ![27_roi_trend_by_month.png](../results/plots/business/27_roi_trend_by_month.png)

# %% [markdown]
# ![28_acquisition_cost_trend_by_month.png](../results/plots/business/28_acquisition_cost_trend_by_month.png)

# %% [markdown]
# ## 14. Correlation Analysis

# %% [markdown]
# ![11_correlation_heatmap.png](../results/plots/eda/11_correlation_heatmap.png)

# %% [markdown]
# ![12_acquisition_cost_vs_revenue_scatter.png](../results/plots/eda/12_acquisition_cost_vs_revenue_scatter.png)

# %% [markdown]
# ## 15. Insights and Recommendations

# %% [markdown]
# ![17_heatmap_channel_campaign_type_revenue.png](../results/plots/eda/17_heatmap_channel_campaign_type_revenue.png)

# %% [markdown]
# ![18_boxplot_roi_by_brand.png](../results/plots/eda/18_boxplot_roi_by_brand.png)

# %% [markdown]
# ![29_heatmap_brand_channel_revenue.png](../results/plots/business/29_heatmap_brand_channel_revenue.png)
